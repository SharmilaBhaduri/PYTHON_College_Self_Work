# %%
5+5
# Out:
# 10

# %%
print("Hello world this is python")
# Out:
# Hello world this is python

# %%
4+6
# Out:
# 10

# %%
5+5
# Out:
# 10

# %%
hi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hi
#
# NameError: name 'hi' is not defined

# %%
print(hi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(hi)
#
# NameError: name 'hi' is not defined

# %%
print("hi")
# Out:
# hi

# %%
print("Last time try to see")
# Out:
# Last time try to see
